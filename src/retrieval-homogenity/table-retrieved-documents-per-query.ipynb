# %% [markdown]
# # Table: Retrieved Documents per query

# %%
from trectools import TrecRun
import pandas as pd
from tqdm import tqdm
from glob import glob
RUN_DIR='/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-probst/retrievalExperiments/runs-ecir22/runs-retrieval-homogenity/'
topics = {int(i.split()[0]): i.split('\t')[1].strip() for i in open('../../Data/topics.retrieval-homogenity.tsv')}

def documents_per_topic(file_name):
    parts = file_name.split('.')
    index = parts[1]
    retrieval_model = parts[2]
    run = TrecRun(RUN_DIR + file_name).run_data
    covered_queries = []
    for _, i in run.groupby('query').size().reset_index(name='count').iterrows():
        covered_queries += [i['query']]
        yield {
            'index': index,
            'retrieval_model': retrieval_model,
            'topic': i['query'],
            'query': topics[i['query']],
            'retrieved_docs': i['count'],
        }
    
    covered_queries = set(covered_queries)
    for topic in topics.keys():
        if topic not in covered_queries:
            yield {
                'index': index,
                'retrieval_model': retrieval_model,
                'topic': topic,
                'query': topics[topic],
                'retrieved_docs': 0,
            }

# %%
df = []

for run_file in tqdm(glob(RUN_DIR + '*.txt')):
    df += [i for i in documents_per_topic(run_file.split('/')[-1])]

df = pd.DataFrame(df)
df
# Out:
# 100%|██████████| 31/31 [13:38<00:00, 26.41s/it]
#                       index   retrieval_model     topic  \
# 0       cc-21-04-anchortext       qld-default   2004033
# 1       cc-21-04-anchortext       qld-default   2004062
# 2       cc-21-04-anchortext       qld-default   2006789
# 3       cc-21-04-anchortext       qld-default   2006876
# 4       cc-21-04-anchortext       qld-default   2007147
# ...                     ...               ...       ...
# 309964  cc-20-05-anchortext  bm25+rm3-default  10909435
# 309965  cc-20-05-anchortext  bm25+rm3-default   9744257
# 309966  cc-20-05-anchortext  bm25+rm3-default   3838516
# 309967  cc-20-05-anchortext  bm25+rm3-default  10115744
# 309968  cc-20-05-anchortext  bm25+rm3-default  11527743
#
#                                  query  retrieved_docs
# 0               good woods for carving            1000
# 1           chance the rapper networth            1000
# 2                   mlb advanced media            1000
# 3               eclectic energies test            1000
# 4       best netflix shows of all time            1000
# ...                                ...             ...
# 309964                      wvlpnboard               0
# 309965               www.spellcity.com               0
# 309966                         kambuta               0
# 309967                        richback               0
# 309968                      ancerstory               0
#
# [309969 rows x 5 columns]

# %%
df_tmp = df[df['retrieval_model'] == 'bm25-conjunction-default'].groupby(['index', 'topic']).sum().reset_index()
df_tmp['terms'] = df.topic.apply(lambda i: len(topics[i].split()))
df_tmp
# Out:
#                      index     topic  retrieved_docs  terms
# 0      cc-19-47-anchortext   2004033               1      4
# 1      cc-19-47-anchortext   2004062               0      4
# 2      cc-19-47-anchortext   2006789               0      3
# 3      cc-19-47-anchortext   2006876               2      3
# 4      cc-19-47-anchortext   2007147               8      6
# ...                    ...       ...             ...    ...
# 39991                orcas  12852544               5      1
# 39992                orcas  12853262               1      1
# 39993                orcas  12853353              20      1
# 39994                orcas  12853486               3      1
# 39995                orcas  12853726               1      1
#
# [39996 rows x 4 columns]

# %%
term_to_query_count = {i['terms']:i['retrieved_docs'] for _, i in df_tmp[df_tmp['index'] == 'ms-marco-content'].groupby('terms').count().reset_index().iterrows()}

# %%
df_tmp['index'].unique()
# Out:
# array(['cc-19-47-anchortext', 'ms-marco-content',
#        'msmarco-document-v1-title-only', 'orcas'], dtype=object)

# %%
df_queries_with_empty_result_set = df_tmp[df_tmp['retrieved_docs'] <= 0].groupby(['index', 'terms']).count().reset_index()[['index', 'terms', 'retrieved_docs']].copy()

df_queries_with_empty_result_set['percentage_empty_results'] = df_queries_with_empty_result_set.apply(lambda i: 1-(i['retrieved_docs']/term_to_query_count[i['terms']]), axis=1)
df_queries_with_empty_result_set
# Out:
#                              index  terms  retrieved_docs  \
# 0              cc-19-47-anchortext      1             601
# 1              cc-19-47-anchortext      2            1120
# 2              cc-19-47-anchortext      3            1337
# 3              cc-19-47-anchortext      4             993
# 4              cc-19-47-anchortext      5             603
# 5              cc-19-47-anchortext      6             187
# 6              cc-19-47-anchortext      7             100
# 7              cc-19-47-anchortext      8              49
# 8              cc-19-47-anchortext      9              18
# 9              cc-19-47-anchortext     10               8
# 10             cc-19-47-anchortext     11               1
# 11             cc-19-47-anchortext     15               1
# 12                ms-marco-content      1              96
# 13                ms-marco-content      2             185
# 14                ms-marco-content      3             204
# 15                ms-marco-content      4             145
# 16                ms-marco-content      5              98
# 17                ms-marco-content      6              23
# 18                ms-marco-content      7              20
# 19                ms-marco-content      8              10
# 20                ms-marco-content      9               2
# 21                ms-marco-content     10               2
# 22                ms-marco-content     12               1
# 23                ms-marco-content     15               1
# 24  msmarco-document-v1-title-only      1             632
# 25  msmarco-document-v1-title-only      2            1322
# 26  msmarco-document-v1-title-only      3            1507
# 27  msmarco-document-v1-title-only      4            1097
# 28  msmarco-document-v1-title-only      5             673
# 29  msmarco-document-v1-title-only      6             246
# 30  msmarco-document-v1-title-only      7             116
# 31  msmarco-document-v1-title-only      8              53
# 32  msmarco-document-v1-title-only      9              20
# 33  msmarco-document-v1-title-only     10               8
# 34  msmarco-document-v1-title-only     11               3
# 35  msmarco-document-v1-title-only     12               1
# 36  msmarco-document-v1-title-only     13               3
# 37  msmarco-document-v1-title-only     15               1
# 38  msmarco-document-v1-title-only     28               1
# 39                           orcas      3               1
#
#     percentage_empty_results
# 0                   0.476936
# 1                   0.520137
# 2                   0.494518
# 3                   0.481733
# 4                   0.496661
# 5                   0.527778
# 6                   0.523810
# 7                   0.443182
# 8                   0.470588
# 9                   0.500000
# 10                  0.750000
# 11                  0.000000
# 12                  0.916449
# 13                  0.920737
# 14                  0.922873
# 15                  0.924322
# 16                  0.918197
# 17                  0.941919
# 18                  0.904762
# 19                  0.886364
# 20                  0.941176
# 21                  0.875000
# 22                  0.666667
# 23                  0.000000
# 24                  0.449956
# 25                  0.433590
# 26                  0.430246
# 27                  0.427453
# 28                  0.438230
# 29                  0.378788
# 30                  0.447619
# 31                  0.397727
# 32                  0.411765
# 33                  0.500000
# 34                  0.250000
# 35                  0.666667
# 36                  0.000000
# 37                  0.000000
# 38                  0.000000
# 39                  0.999622

# %%
# 1000 Random documents for homogenity evaluation

# %%
MARCO_TOPICS = [i['topic'] for _, i in df_tmp[(df_tmp['retrieved_docs'] >= 800) & (df_tmp['index'] == 'ms-marco-content')].iterrows()]
ANCHOR_TOPICS = [i['topic'] for _, i in df_tmp[(df_tmp['retrieved_docs'] >= 800) & (df_tmp['index'] == 'cc-19-47-anchortext')].iterrows()]

topics_conjunction = set(ANCHOR_TOPICS).intersection(set(MARCO_TOPICS))

json.dump([i for i in topics_conjunction], open('topics-for-homogenity-evaluation_conjunction.json', 'w'))

# %%
len(ANCHOR_TOPICS)
# Out:
# 44

# %%
from random import shuffle
import json
df_tmp = df[df['retrieval_model'] == 'bm25-default'].groupby('topic').sum().reset_index()
random_topics = [i for i in df_tmp[df_tmp['retrieved_docs'] >= 8000].topic]

shuffle(random_topics)
json.dump(random_topics[:1000], open('topics-for-homogenity-evaluation.json', 'w'))

# %%
# !cat topics-for-homogenity-evaluation.json
# Out:
# [2689528, 5252102, 11574750, 9059837, 2658813, 7956181, 2576073, 5830387, 8281267, 11208713, 10848880, 8255800, 12285000, 11740115, 10414970, 6970416, 6053354, 7159891, 9433994, 10681608, 9733926, 12522869, 11816304, 2028315, 11959893, 3288833, 10436098, 4595179, 4216769, 3960392, 4878201, 11456573, 7292700, 4181272, 11052419, 11416630, 9557090, 6071639, 8381438, 2237527, 9098907, 9602955, 3289137, 12180237, 5346076, 7887782, 3960987, 11094636, 4885932, 7458982, 12277572, 3317142, 4938566, 12278496, 8383624, 7025065, 2942309, 11798147, 9758943, 6774687, 8960295, 7571218, 5725131, 4555319, 2704695, 6099117, 10589927, 12842711, 6925733, 3958146, 11926146, 8142819, 3901245, 7995938, 2618400, 5752218, 4106057, 9159829, 2798261, 3583479, 11216005, 10853742, 12048756, 8053964, 7253672, 4314960, 12685633, 9737489, 4364725, 4763745, 7873592, 6689522, 7851559, 11820637, 12446296, 12844550, 5770320, 11306972, 11752202, 11004867, 10059874, 5683920, 9478551, 4255979, 9813413, 10525362, 7185532, 9710259, 4995074, 5664279, 4118370, 8860060, 5703647, 4568127, 9449231, 12427639, 7773241, 5015099, 4691984, 8155777, 5010100, 10073216, 2270596, 7268205, 11958021, 6689603, 6824095, 10161540, 4759478, 11744570, 8913837, 5581631, 11525272, 7053104, 9854647, 2469149, 6852709, 4948353, 9130842, 10321181, 6099451, 7557665, 5120125, 3162303, 4465122, 8910062, 4618910, 8591946, 8433171, 10242391, 7614539, 3527613, 4496984, 6346985, 8978550, 10495776, 6811136, 9688068, 3335339, 2298033, 2829571, 2381688, 8911208, 12322190, 4734193, 6462010, 6895121, 6969739, 2251472, 8344077, 4252455, 4459567, 6977693, 5222133, 6313760, 3924220, 5063332, 3017470, 12389234, 12391477, 11059438, 6445434, 6949978, 11777957, 2035824, 12357941, 10591235, 5562473, 2623468, 6102255, 2507354, 8214767, 7108310, 11038864, 8864900, 2776303, 2701601, 10763973, 9998667, 2621560, 10522803, 8787633, 11333741, 12454185, 10198521, 4689931, 11779539, 2097206, 2093691, 10717625, 10080446, 5035755, 12805353, 6189124, 6111717, 5042712, 4691815, 12434040, 10277201, 5516217, 4810609, 8536674, 3138906, 5927280, 12159286, 7661260, 6451802, 8717659, 2594920, 5156278, 4196002, 2886625, 5121192, 5976006, 11278212, 2996953, 3481589, 6238986, 9722206, 9211486, 10906352, 9178866, 7977400, 8398820, 11734180, 9391031, 7623771, 9164586, 12363802, 5602881, 5511075, 10688394, 10203317, 5772742, 7737355, 11922470, 3945280, 2737387, 2945212, 7056074, 3045055, 12740376, 5373642, 6621438, 11315524, 6378773, 11049752, 11800679, 3480764, 3067359, 2925328, 7317882, 7667440, 4826327, 6870523, 8851494, 5429197, 6038966, 8326281, 4667487, 6110166, 7371688, 2564652, 9555445, 2042794, 10262487, 6915083, 3584747, 11249131, 2731807, 9713630, 12690570, 7198105, 9774634, 9764628, 2890581, 6532768, 10330898, 7527377, 2080299, 10341732, 6645345, 10780387, 11438648, 3866902, 7495404, 11412117, 9043117, 11077130, 8532051, 4423560, 6927821, 9109350, 11689831, 3098524, 2836401, 12382863, 9511688, 7411368, 2903687, 5190196, 8400153, 10191197, 5372818, 11565953, 2954042, 2907822, 12013270, 6455928, 3577842, 3106879, 2835830, 9492537, 10842011, 12255682, 7844025, 10622545, 6573251, 3306163, 11362772, 10360723, 4861276, 9471334, 6285908, 4513899, 10365510, 2039391, 6061799, 8668586, 10888034, 11107567, 6132755, 2744634, 4892070, 4109107, 11032954, 5880722, 4723340, 8723575, 6747388, 6242092, 6002638, 3478981, 12061890, 10618860, 11859167, 12653716, 4609759, 12494038, 9986763, 4812864, 8138004, 4092644, 9588617, 11194416, 12009362, 6314796, 6477828, 4672441, 3720279, 5198655, 10794669, 6296495, 5935186, 9383886, 9406265, 10855329, 7801528, 3469722, 12736840, 4114632, 3623802, 7224129, 7125394, 5081617, 5340193, 5068890, 11250672, 7358111, 7812203, 9052277, 8418791, 10525075, 3322591, 4757605, 10901789, 10518923, 6367285, 3849315, 10821722, 2159468, 10963514, 4627104, 10431900, 7602587, 11975707, 10338164, 5391603, 5166214, 12564464, 8095512, 6877876, 5854713, 8433537, 2254595, 2790343, 10918994, 8537564, 3998091, 3684641, 9159793, 11 ...

# %%
df[df['retrieved_docs'] <= 0].groupby('index').size()
# Out:
# index
# cc-16-07-anchortext               2100
# cc-17-04-anchortext               1980
# cc-18-13-anchortext               1935
# cc-19-47-anchortext               1962
# cc-20-05-anchortext               1917
# cc-21-04-anchortext               1959
# ms-marco-content                  1251
# msmarco-document-v1-title-only    2430
# orcas                                6
# dtype: int64

# %%
2430/30000
# Out:
# 0.081

# %%
del_run.run_data.groupby('query').size().reset_index(name='count').sort_values('count')
# Out:
#          query  count
# 6225   9348986      1
# 5872   8917600      1
# 5322   8298567      1
# 7008  10268261      1
# 5806   8850508      1
# ...        ...    ...
# 3100   5728387   1000
# 3101   5729069   1000
# 3102   5730324   1000
# 3122   5755588   1000
# 9299  12853726   1000
#
# [9300 rows x 2 columns]
